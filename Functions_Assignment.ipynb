# %% [markdown]
# # Theory Questions
#
# 1. What is the difference between a function and a method in Python?
# - A function is a block of code that is defined usinf def keyword
# - A function doesnt require class to be defined and works as an individual entity
# - syntax :
#           def add(a,b):
#               return a+b
#           add(10,20)
# - A method is defined under a class
# - It is required to create an object for the class so as to be called and run
# - Used for for defining a certain block of reusable code
# -syntax :
#         class clac:
#           def add(a,b):
#             return a+b
#         obj = calc()
#         obj.add(10,20)
#
# 2. Explain the concept of function arguments and parameters in Python.
# - A function is a block of reusable code , executed when called
# - It also has parameters and arguments
# - But when we pass the input to the function for further computation during its call it act as arguments .
# - WHen the function is defined and there the variables used to catch the arguments and compute using those variables its refered to as parameters.
# - Example:
#           def fun(parameter1,parameter2):
#             return parameter1+parameter2
#           argument1 = 10
#           argument2 = 20
#           fun(argument1 , argument2)
#
# 3. What are the different ways to define and call a function in Python?
# - defining functions:
#   - Function without parameter:
#     syntax:
#         def func():
#           return 100
#         func()
#   - FUnction with parameter:
#       syntax:
#         def func(a,b):
#           return a+b
#         func(10,20)
#   - Function with default parameters:
#        syntax:
#         def func(a,b=10):
#           return a+b
#         func(10)
#   - Function with variable length arguments:
#          syntax:
#         def func(*args,**kargs):
#           return args , kargs
#         func(10,20,30,a=40,b=50)
#   - Anonymous function:
#       funt = lambda x:x**2
#       print(funt([10,20,30]))
#   - Nested function:
#       def funt(a):
#         def runt(a):
#           return a+1
#       funt(10)
# - functions calling:
#   - functions as argument:
#       syntax:
#           def funt(func,value):
#             return func(value)
#           funt(lambda x:x*2 , 10)
#   - Unpacking arguments-
#       syntax:
#           def func(*val):
#             a=0
#             for i in range(0,len(val)):
#               a += val[i]
#             print a
#           valuess = [10,20,30]
#           func(valuess)
#   - positional argument:
#       syntax:
#             def func(a,b):
#                return a+b
#             func(10,20)
#   - default argument:
#       syntax:
#               def func(a,b=10):
#                   return a+b
#               func(10,20)
#   - keyword argument:
#       syntax:
#               def func(a,b):
#                   return a+b
#               func(b=10,a=20)
# 4. What is the purpose of the `return` statement in a Python function?
# - The purpose of return statement is to return a values of specific data type instead of returning null
# - THe function sometimes to specify the return type of it , bydefault the return type of a function is null
# - Printing doesnt mean that the function has a specific return values , its just an instruction
# - Example:
#         def func(a):
#           return a+1
#         a= func(10)
#         print(a)  \\output is 11
#
# 5. What are iterators in Python and how do they differ from iterables?
# - Iterators : Iterators are the object which is to be iterated as these are the intermediate values to be iterated
# - As iterators are the intermediatery objects , the iterables are the data or group of data specified in a particular data structure Which can be iterated
#
# 6. Explain the concept of generators in Python and how they are defined.
# - Generators are the functions which use yield instead of return as the yield stops the output of the function and is generated or carried out to run further with the use of next() function which is alredady pre defined.
# Exapmple:
#       syntax:
#           def func(*args):
#             for i in range(len(args)):
#               yield args[i]+1
#           a = func(list(10,20,30))
#           next(a)
#           next(a)
#           next(a)
#
# 7. What are the advantages ,of using generators over regular functions?
# - Using generator functions takes less memory space as the computations are not performed at once
# - It takes less time to compute and give results
# - Used to drive and compute a large number of computations which might take a lot of time to execute
#
# 8. What is a lambda function in Python and when is it typically used?
# - lambda funtion is a type of function which doesnt need to to be formally defined as it is utilised with an ease of single line satement
# - IT is typically used for a single time use of the functions
# - used in functions like map(),filter() sorted(value,key=lambda statement:expression)
#
# 9. Explain the purpose and usage of the `map()` function in Python.
# - Purpose:
#   - map() function is used to derive a combinational mapping between the function and the values .
#   - THe map() function is used to execute a set of instructions into an iterables fo rfaster and single line execution
# - Usage:
#   - Used to give a certain set of values while performing certain functional and operable code to the specific values
#   - Used for multiple iterables to get a specific output together
#
# 10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python? list:[47,11,42,13];
# - map():
#          listt=[47,11,42,13]
#          a=[]
#          a=map(lambda x:x-10 , listt)
#          print(a)
#          Will give the list that has reduced every value of list by 10
# - reduce():
#          listt=[47,11,42,13]
#          a = reduce(lambda x,y:x+y , listt)
#          print(a)
#          will give the output of all the values addition
# - filter():
#         listt=[47,11,42,13]
#          a=[]
#          a=filter(lambda x: x>40 , listt)
#          print(a)
#          Will give the values greater then 40
#  11. Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given (Attach paper image for this answer) in doc or colab notebook.

# %% [markdown]
# ![WhatsApp Image 2025-08-19 at 13.24.59_1e2c7c86.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Practical Questions

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def func(nums):
  s = 0
  for i in nums :
    if i%2 == 0 :
      s+=i
  return s

func([10,20,30,40,55,93])
# Out:
# 100

# %%
# 2. Create a Python function that accepts a string and returns the reverse of that string.

def func(str) :
  return str[::-1]

func("Salute")
# Out:
# 'etulaS'

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.

def func(nums) :
  return [i**2 for i in nums]

func([10 , 20 , 30 , 40])
# Out:
# [100, 400, 900, 1600]

# %%
# 4. Write a Python function that checks if a given number is prime or not from 1 to 200.

def func(numb) :

  for i in range(2,numb) :
      if numb % i == 0:
        return 'no'

  else :
        c= 'yes'
  return c

number = int(input("Enter a number"))
func(number)
# Out:
# Enter a number2
# 'yes'

# %%
# 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
def fib(number) :
  a=0
  b=1
  for i in range(0,number+1):
    yield a
    a,b = b,a+b
a=fib(5)

# %%
next(a)
# Out:
# 0

# %%
next(a)
# Out:
# 1

# %%
next(a)
# Out:
# 1

# %%
# 6. Write a generator function in Python that yields the powers of 2 up to a given exponent.

def fun(number):
  for i in range(1,number+1):
    yield 2**i

a = fun(10)

# %%
next(a)
# Out:
# 2

# %%
next(a)
# Out:
# 4

# %%
next(a)
# Out:
# 8

# %%
# 7. Implement a generator function that reads a file line by line and yields each line as a string.

def read_file_line_by_line(filename):
  with open(filename, 'r') as file:
    for line in file:
      yield line.rstrip('\n')

for line in read_file_line_by_line("example.txt"):
    print(line)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1010730007.py in <cell line: 0>()
#       6       yield line.rstrip('\n')
#       7
# ----> 8 for line in read_file_line_by_line("example.txt"):
#       9     print(line)
#
# /tmp/ipython-input-1010730007.py in read_file_line_by_line(filename)
#       2
#       3 def read_file_line_by_line(filename):
# ----> 4   with open(filename, 'r') as file:
#       5     for line in file:
#       6       yield line.rstrip('\n')
#
# FileNotFoundError: [Errno 2] No such file or directory: 'example.txt'

# %%
# 8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.

def func(par):
  return sorted(par, key=lambda par: par[1])

listt = [(10,5),(15,2),(11,1)]
print(func(listt))
# Out:
# (15, 2)
# [(11, 1), (15, 2), (10, 5)]

# %%
# 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.

def func(par):
    return map(lambda x:(((9/5)*x)+32),par)

listt = [30,20,10]
a = func(listt)

# %%
next(a)
# Out:
# 86.0

# %%
# 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.

def func(para):
  vowels = "aeiouAEIOU"
  filtered_chars = filter(lambda x: x not in vowels, para)
  return filtered_chars

a = func('there is a lot of things a man')

# %%
next(a)
# Out:
# 't'

# %%
next(a)
# Out:
# 'h'

# %%
next(a)
# Out:
# 'r'

# %%
# 11. Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this: Write a Python program, which returns a list with 2-tuples. /Each tuple consists of the order number and the product of the price per item and the quantity. The product should be increased by 10,- € if the value of the order is smaller than 100,00 €. Write a Python program using lambda and map.

orders = [
    [34587, "Learning Python, Mark Lutz", 4, 40.95],
    [98762, "Programming Python, Mark Lutz", 5, 56.80],
    [77226, "Head First Python, Paul Barry", 3, 32.95],
    [88112, "Einführung in Python3, Bernd Klein", 3, 24.99]
]
result = list(map(lambda x: (x[0], x[2] * x[3] if x[2] * x[3] >= 100 else x[2] * x[3] + 10),orders))
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
